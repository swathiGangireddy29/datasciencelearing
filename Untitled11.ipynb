# %% [markdown]
# <a href="https://colab.research.google.com/github/swathiGangireddy29/datasciencelearing/blob/main/Untitled11.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import numpy as np
df = pd.read_csv("/content/student_marks_outlier_dataset (2).csv")

# %%
df
# Out:
#     Student_ID  Marks
# 0            1     58
# 1            2     62
# 2            3     65
# 3            4     67
# 4            5     69
# 5            6     70
# 6            7     71
# 7            8     72
# 8            9     73
# 9           10     74
# 10          11     75
# 11          12     76
# 12          13     78
# 13          14     80
# 14          15     82
# 15          16     84
# 16          17     85
# 17          18     87
# 18          19     90
# 19          20    250

# %%
print("mean",df["Marks"].mean())
print("median",df["Marks"].median())
print("mode",df["Marks"].mode())
# Out:
# mean 83.4
# median 74.5
# mode 0      58
# 1      62
# 2      65
# 3      67
# 4      69
# 5      70
# 6      71
# 7      72
# 8      73
# 9      74
# 10     75
# 11     76
# 12     78
# 13     80
# 14     82
# 15     84
# 16     85
# 17     87
# 18     90
# 19    250
# Name: Marks, dtype: int64

# %%
#dispersions
print("variance",df["Marks"].var())
print("standard deviation",df["Marks"].std())
# Out:
# variance 1608.4631578947367
# standard deviation 40.10564994978559
