# %% [markdown]
# <a href="https://colab.research.google.com/github/swathiGangireddy29/datasciencelearing/blob/main/Untitled4.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import  pandas as pd

# %%
student_df = pd.read_csv('students.csv')

# %%
marks_df = pd.read_csv('marks.csv')

# %%
#inner merge
#it will takes only common data from tables

result = pd.merge(
    student_info_df,
    marks_df,
    on='student_id',
    how='inner'
)
print(result)
# Out:
#    student_id    name department        city  python  sql  machine_learning
# 0         101    Ravi        CSE   Hyderabad      85   80                75
# 1         102   Priya        ECE  Vijayawada      90   85                88
# 2         103   Kiran        CSE      Guntur      78   70                72
# 3         105   Arjun       MECH   Bangalore      88   92                85
# 4         106   Meena      CIVIL   Hyderabad      76   75                70
# 5         107   Rahul        CSE       Vizag      95   90                96
# 6         109  Vikram        EEE     Chennai      81   79                77
# 7         110  Anitha       MECH   Bangalore      89   91                90

# %%
#left merge
#allow rows from left dataframe

# %%
result_l = pd.merge(
    student_df,
    marks_df,
    on = 'student_id',
    how = 'left'
)
print(result_l)
# Out:
#    student_id  python_x  sql_x  machine_learning_x  python_y  sql_y  \
# 0         101        85     80                  75        85     80
# 1         102        90     85                  88        90     85
# 2         103        78     70                  72        78     70
# 3         105        88     92                  85        88     92
# 4         106        76     75                  70        76     75
# 5         107        95     90                  96        95     90
# 6         111        67     60                  65        67     60
# 7         112        72     68                  66        72     68
# 8         109        81     79                  77        81     79
# 9         110        89     91                  90        89     91
#
#    machine_learning_y
# 0                  75
# 1                  88
# 2                  72
# 3                  85
# 4                  70
# 5                  96
# 6                  65
# 7                  66
# ...

# %%
result_l = pd.merge(
    student_df,
    marks_df,
    on = 'student_id',
    how = 'right'
)
print(result_l)
# Out:
#    student_id  python_x  sql_x  machine_learning_x  python_y  sql_y  \
# 0         101        85     80                  75        85     80
# 1         102        90     85                  88        90     85
# 2         103        78     70                  72        78     70
# 3         105        88     92                  85        88     92
# 4         106        76     75                  70        76     75
# 5         107        95     90                  96        95     90
# 6         111        67     60                  65        67     60
# 7         112        72     68                  66        72     68
# 8         109        81     79                  77        81     79
# 9         110        89     91                  90        89     91
#
#    machine_learning_y
# 0                  75
# 1                  88
# 2                  72
# 3                  85
# 4                  70
# 5                  96
# 6                  65
# 7                  66
# ...

# %%
result_l  = pd.merge(
    student_df,
    marks_df,
    on = 'student_id',
    how = 'outer'
)
print(result_l)
# Out:
#    student_id  python_x  sql_x  machine_learning_x  python_y  sql_y  \
# 0         101        85     80                  75        85     80
# 1         102        90     85                  88        90     85
# 2         103        78     70                  72        78     70
# 3         105        88     92                  85        88     92
# 4         106        76     75                  70        76     75
# 5         107        95     90                  96        95     90
# 6         109        81     79                  77        81     79
# 7         110        89     91                  90        89     91
# 8         111        67     60                  65        67     60
# 9         112        72     68                  66        72     68
#
#    machine_learning_y
# 0                  75
# 1                  88
# 2                  72
# 3                  85
# 4                  70
# 5                  96
# 6                  77
# 7                  90
# ...
