# %% [markdown]
# <a href="https://colab.research.google.com/github/swathiGangireddy29/datasciencelearing/blob/main/regression.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import numpy as np
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler
from sklearn.neighbors import KNeighborsRegressor
from sklearn.metrics import mean_squared_error
from sklearn.metrics import mean_absolute_error
from sklearn.metrics import r2_score

# %%
df = pd.read_csv('/content/knnregression (1).csv')

# %%
df

# %%
df.head()

# %%
df.isnull().sum()

# %%
df.duplicated().sum()
# Out:
# np.int64(0)

# %%
df.describe()

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 500 entries, 0 to 499
# Data columns (total 5 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   House_Size_sqft      500 non-null    int64
#  1   Bedrooms             500 non-null    int64
#  2   Age_of_House         500 non-null    int64
#  3   Distance_to_City_km  500 non-null    float64
#  4   Price_Lakhs          500 non-null    float64
# dtypes: float64(2), int64(3)
# memory usage: 19.7 KB

# %%
df.corr()
# Out:
#                      House_Size_sqft  ...  Price_Lakhs
# House_Size_sqft             1.000000  ...     0.977515
# Bedrooms                    0.891500  ...     0.905370
# Age_of_House               -0.013785  ...    -0.136553
# Distance_to_City_km        -0.031477  ...    -0.163530
# Price_Lakhs                 0.977515  ...     1.000000
#
# [5 rows x 5 columns]

# %%
X = df[
  [
      'House_Size_sqft',
      'Bedrooms',
      'Age_of_House',
      'Distance_to_City_km']]
Y = df['Price_Lakhs']

# %%
X_train, X_test, Y_train, Y_test = train_test_split(
    X,
    Y,
    test_size = 0.2,
    random_state = 42

)

# %%
print(X_train.shape)
print(X_test.shape)
print(Y_train.shape)
print(Y_test.shape)
# Out:
# (400, 4)
# (100, 4)
# (400,)
# (100,)

# %%
scaler = StandardScaler()
X_train = scaler.fit_transform(X_train)
X_test = scaler.transform(X_test)

# %%
knn = KNeighborsRegressor(
    n_neighbors = 5
)

# %%
knn.fit(X_train, Y_train)
# Out:
# KNeighborsRegressor()

# %%
y_pred = knn.predict(X_test)

# %%
mae = mean_absolute_error(Y_test, y_pred)
print('Mean Absolute Error:', mae)
mse = mean_squared_error(Y_test, y_pred)
print('Mean Squared Error:', mse)
rmse = np.sqrt(mse)
print('Root Mean Squared Error:', rmse)
r2 = r2_score(Y_test, y_pred)
print('R2 Score:', r2)
# Out:
# Mean Absolute Error: 7.889000000000001
# Mean Squared Error: 95.20108400000001
# Root Mean Squared Error: 9.757104283546425
# R2 Score: 0.9800639563781013

# %%
new_house = [[1700,3,4,5]]
new_house_scaled = scaler.transform(new_house)
pred = knn.predict(new_house_scaled)
print(pred[0])
# Out:
# 224.96000000000004
